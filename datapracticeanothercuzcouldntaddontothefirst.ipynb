# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/onlinefoods.csv')

# %%
df.head(3)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
df.isna()
# Out:
#        Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0    False   False           False       False           False
# 1    False   False           False       False           False
# 2    False   False           False       False           False
# 3    False   False           False       False           False
# 4    False   False           False       False           False
# ..     ...     ...             ...         ...             ...
# 383  False   False           False       False           False
# 384  False   False           False       False           False
# 385  False   False           False       False           False
# 386  False   False           False       False           False
# 387  False   False           False       False           False
#
#      Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                         False        False     False      False     False
# ...

# %%
df.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
df.isnull()
# Out:
#        Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0    False   False           False       False           False
# 1    False   False           False       False           False
# 2    False   False           False       False           False
# 3    False   False           False       False           False
# 4    False   False           False       False           False
# ..     ...     ...             ...         ...             ...
# 383  False   False           False       False           False
# 384  False   False           False       False           False
# 385  False   False           False       False           False
# 386  False   False           False       False           False
# 387  False   False           False       False           False
#
#      Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                         False        False     False      False     False
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
coltokeep = ['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
       'Educational Qualifications', 'Family size','Output', 'Feedback']
coltodrop = ['latitude', 'longitude',
       'Pin code','Unnamed: 12']

# %%
df.shape
# Out:
# (388, 13)

# %%
df = df[coltokeep]

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'Output', 'Feedback'],
#       dtype='object')

# %%
df.rename(columns = {'Marital Status': 'Marriage'} ,inplace= True)

# %%
df.head(1)
# Out:
#    Age  Gender Marriage Occupation Monthly Income Educational Qualifications  \
# 0   20  Female   Single    Student      No Income              Post Graduate
#
#    Family size Output  Feedback
# 0            4    Yes  Positive

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 383     True
# 384     True
# 385     True
# 386    False
# 387     True
# Length: 388, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(144)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marriage                      0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# Output                        0
# Feedback                      0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    244
# Name: count, dtype: int64

# %%
#if we need age in months

# %%
df['Age in months'] = df['Age'] * 12

# %%
df.head()
# Out:
#    Age  Gender Marriage Occupation  Monthly Income Educational Qualifications  \
# 0   20  Female   Single    Student       No Income              Post Graduate
# 1   24  Female   Single    Student  Below Rs.10000                   Graduate
# 2   22    Male   Single    Student  Below Rs.10000              Post Graduate
# 3   22  Female   Single    Student       No Income                   Graduate
# 4   22    Male   Single    Student  Below Rs.10000              Post Graduate
#
#    Family size Output   Feedback  Age in months
# 0            4    Yes   Positive            240
# 1            3    Yes   Positive            288
# 2            3    Yes  Negative             264
# 3            6    Yes   Positive            264
# 4            4    Yes   Positive            264

# %%
#male is M female is F

# %%
df['Gender'].apply(lambda x: 'F' if x == 'Female' else 'M')
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 355    M
# 363    M
# 369    M
# 374    M
# 386    M
# Name: Gender, Length: 244, dtype: object

# %%
df['Gender'] = df['Gender'].apply(lambda x: 'F' if x == 'Female' else 'M')

# %%
df.head()
# Out:
#    Age Gender Marriage Occupation  Monthly Income Educational Qualifications  \
# 0   20      M   Single    Student       No Income              Post Graduate
# 1   24      M   Single    Student  Below Rs.10000                   Graduate
# 2   22      M   Single    Student  Below Rs.10000              Post Graduate
# 3   22      M   Single    Student       No Income                   Graduate
# 4   22      M   Single    Student  Below Rs.10000              Post Graduate
#
#    Family size Output   Feedback  Age in months
# 0            4    Yes   Positive            240
# 1            3    Yes   Positive            288
# 2            3    Yes  Negative             264
# 3            6    Yes   Positive            264
# 4            4    Yes   Positive            264

# %%
# __¶_____________________________________________¶
# __¶¶___________________________________________¶¶
# __¶¶¶¶________________________________________¶¶¶
# __¶¶_¶¶_____________________________________¶¶_¶¶
# __¶¶__¶¶___________________________________¶¶__¶¶
# __¶¶_¶_¶¶_________________________________¶¶_¶_¶¶
# __¶¶__¶__¶_______________________________¶¶_¶__¶¶
# __¶¶___¶__¶¶____________________________¶__¶___¶¶
# ___¶¶___¶¶_¶¶_________________________¶¶__¶___¶¶
# ____¶¶___¶¶_¶¶_______________________¶¶_¶¶___¶¶¶
# _____¶¶___¶¶__¶_____________________¶¶_¶¶____¶¶
# ______¶¶___¶¶__¶¶__________________¶__¶¶___¶¶¶
# _______¶¶____¶¶_¶¶_______________¶¶_¶¶¶____¶¶
# ________¶¶____¶¶_¶¶_____________¶¶_¶¶____¶¶¶
# _________¶¶____¶¶__¶¶__________¶__¶¶____¶¶¶
# __________¶¶_____¶¶_¶¶_______¶¶__¶¶____¶¶
# ___________¶¶_____¶¶_¶¶_____¶¶_¶¶_____¶¶
# _____________¶¶____¶¶__¶¶__¶__¶¶____¶¶¶
# ______________¶¶¶____¶¶_¶¶¶_¶¶¶___¶¶¶
# ________________¶¶¶___¶¶__¶¶¶___¶¶¶¶
# __________________¶¶¶___¶¶_¶¶__¶¶¶
# ____________________¶¶¶__¶¶_¶¶¶¶
# ____________________¶_¶¶¶__¶¶_¶¶___¶¶¶¶¶¶
# _________¶¶¶¶¶¶¶¶_¶¶_¶¶_¶¶__¶¶_¶¶¶¶¶¶¶¶_¶¶
# ________¶¶_¶¶¶¶¶¶¶¶_¶¶_¶¶¶¶¶__¶¶¶¶¶¶__¶¶_¶¶
# ________¶¶¶¶___¶¶¶¶¶__¶¶___¶¶¶¶¶¶¶¶¶¶__¶¶¶¶
# _____________¶¶¶¶¶¶¶¶¶_______¶¶¶¶¶_¶¶¶
# ___________¶¶¶_¶_¶¶¶¶¶______¶¶¶_¶¶¶_¶¶¶¶
# __________¶¶¶_¶_¶¶__¶¶¶_____¶¶¶__¶¶¶__¶¶¶
# _________¶¶_¶¶_¶¶__¶¶_¶_____¶_¶¶__¶¶_¶_¶¶¶
# _______¶¶¶_¶_¶¶¶__¶¶_¶¶_____¶¶_¶___¶¶_¶¶_¶¶¶
# ______¶¶_¶¶_¶¶¶____¶¶¶_______¶¶¶_____¶¶_¶_¶¶¶¶
# _¶¶¶¶¶¶_¶_¶¶¶_________________________¶¶_¶¶_¶¶¶¶¶¶
# ¶¶____¶¶_¶¶¶____________________________¶¶_¶¶____¶
# ¶¶_____¶¶¶¶______________________________¶¶_____¶¶
# _¶¶¶____¶¶_______________________________¶____¶¶¶
# __¶¶¶¶__¶¶_______________________________¶¶¶¶¶¶¶
# ____¶¶¶¶¶_________________________________¶¶¶

# %%
df = pd.read_csv('/content/Books_Data_Clean.csv')

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
df.columns = df.columns.str.capitalize()

# %%
df.head()
# Out:
#    Index  Publishing year                        Book name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author Language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_rating  Book_average_rating  Book_ratings_count          Genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.describe()
# Out:
#              Index  Publishing year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         Gross sales  Publisher revenue   Sale price   Sales rank    Units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
#we see -560 as publishing year so bad data so we create mask of likr around 1900 cuz 25% was 1900

# %%
df['Publishing year'] > 1900
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1065    True
# 1066    True
# 1067    True
# 1068    True
# 1069    True
# Name: Publishing year, Length: 1070, dtype: bool

# %%
df[df['Publishing year'] > 1900]
# Out:
#       Index  Publishing year                        Book name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author Language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df = df[df['Publishing year'] > 1900]

# %%
df.head()
# Out:
#    Index  Publishing year                        Book name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author Language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_rating  Book_average_rating  Book_ratings_count          Genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.describe()
# Out:
#              Index  Publishing year  Book_average_rating  Book_ratings_count  \
# count  1009.000000      1009.000000          1009.000000         1009.000000
# mean    535.926660      1994.730426             4.012230        94817.793855
# std     308.769358        23.204719             0.246492        31473.890412
# min       0.000000      1901.000000             2.970000        27308.000000
# 25%     271.000000      1989.000000             3.860000        70701.000000
# 50%     535.000000      2003.000000             4.030000        89204.000000
# 75%     802.000000      2010.000000             4.180000       113400.000000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         Gross sales  Publisher revenue   Sale price   Sales rank    Units sold
# count   1009.000000        1009.000000  1009.000000  1009.000000   1009.000000
# mean    1832.644985         841.360638     4.844311   613.314172   9744.482656
# ...

# %%
df.isna().sum()
# Out:
# Index                   0
# Publishing year         0
# Book name              21
# Author                  0
# Language_code          49
# Author_rating           0
# Book_average_rating     0
# Book_ratings_count      0
# Genre                   0
# Gross sales             0
# Publisher revenue       0
# Sale price              0
# Sales rank              0
# Publisher               0
# Units sold              0
# dtype: int64

# %%
# we keep these entries cuz if we delelte it we might lose some important data  like dropping one son language code might delte the books with the most sales thats why but we can drop book names tho cuz if we dont know the book we anyway arent gonna find which it is

# %%
#ONLY DROPPING BOOKNAMES NA VALES AND KEEPING LANGUAGE CODES NA VALUES

# %%
df.dropna(subset = {'Book name'},inplace = True)
# Out:
# /tmp/ipython-input-991061041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset = {'Book name'},inplace = True)

# %%
df.head()
# Out:
#    Index  Publishing year                        Book name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author Language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_rating  Book_average_rating  Book_ratings_count          Genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.isna().sum()
# Out:
# Index                   0
# Publishing year         0
# Book name               0
# Author                  0
# Language_code          47
# Author_rating           0
# Book_average_rating     0
# Book_ratings_count      0
# Genre                   0
# Gross sales             0
# Publisher revenue       0
# Sale price              0
# Sales rank              0
# Publisher               0
# Units sold              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.hist(df["Publishing year"])
plt.xlabel("Year")
plt.ylabel("Distribution in publishing year")
plt.title("Distribution of publishing year")
plt.show()

# %%
df['Genre'].value_counts().sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel("Genre")
plt.ylabel("Distribution in Genre")
plt.title("Genre vs Distribution")
plt.show()

# %%
df['Genre'].value_counts().sort_values(ascending = True).plot(kind = 'bar')
plt.xlabel("Genre")
plt.ylabel("Distribution in Genre")
plt.title("Genre vs Distribution")
plt.show()

# %%
df.groupby("Author")["Book_average_rating"].mean().sort_values(ascending = False)
# Out:
# Author
# Bill Watterson                  4.650000
# Bill Watterson, G.B. Trudeau    4.610000
# J.R.R. Tolkien                  4.590000
# George R.R. Martin              4.560000
# Sarah J. Maas                   4.526000
#                                   ...
# Chetan Bhagat                   3.273333
# Audrey Niffenegger              3.230000
# Herman Koch, Sam Garrett        3.220000
# P.D. James                      3.210000
# Sue Monk Kidd                   3.100000
# Name: Book_average_rating, Length: 669, dtype: float64

# %%
sns.boxplot(x = "Genre" , y = "Book_average_rating", data = df)
plt.xlabel("Genre")
plt.ylabel("Book_average_rating")
plt.title("Author vs Book_average_rating")
plt.show()

# %%
sns.scatterplot(x = "Sale price", y = "Gross sales", data = df)
plt.xlabel("Sale price")
plt.ylabel("Gross sales")
plt.title("Sale price vs Gross sales")
plt.show()

# %%
df.groupby("Publishing year")["Units sold"].sum().sort_values(ascending = False).plot(kind = 'line',marker = 'o')
plt.xlabel("Publishing year")
plt.ylabel("Units sold")
plt.title("Publishing year vs Units sold")
plt.show()

# %%
# __¶_____________________________________________¶
# __¶¶___________________________________________¶¶
# __¶¶¶¶________________________________________¶¶¶
# __¶¶_¶¶_____________________________________¶¶_¶¶
# __¶¶__¶¶___________________________________¶¶__¶¶
# __¶¶_¶_¶¶_________________________________¶¶_¶_¶¶
# __¶¶__¶__¶_______________________________¶¶_¶__¶¶
# __¶¶___¶__¶¶____________________________¶__¶___¶¶
# ___¶¶___¶¶_¶¶_________________________¶¶__¶___¶¶
# ____¶¶___¶¶_¶¶_______________________¶¶_¶¶___¶¶¶
# _____¶¶___¶¶__¶_____________________¶¶_¶¶____¶¶
# ______¶¶___¶¶__¶¶__________________¶__¶¶___¶¶¶
# _______¶¶____¶¶_¶¶_______________¶¶_¶¶¶____¶¶
# ________¶¶____¶¶_¶¶_____________¶¶_¶¶____¶¶¶
# _________¶¶____¶¶__¶¶__________¶__¶¶____¶¶¶
# __________¶¶_____¶¶_¶¶_______¶¶__¶¶____¶¶
# ___________¶¶_____¶¶_¶¶_____¶¶_¶¶_____¶¶
# _____________¶¶____¶¶__¶¶__¶__¶¶____¶¶¶
# ______________¶¶¶____¶¶_¶¶¶_¶¶¶___¶¶¶
# ________________¶¶¶___¶¶__¶¶¶___¶¶¶¶
# __________________¶¶¶___¶¶_¶¶__¶¶¶
# ____________________¶¶¶__¶¶_¶¶¶¶
# ____________________¶_¶¶¶__¶¶_¶¶___¶¶¶¶¶¶
# _________¶¶¶¶¶¶¶¶_¶¶_¶¶_¶¶__¶¶_¶¶¶¶¶¶¶¶_¶¶
# ________¶¶_¶¶¶¶¶¶¶¶_¶¶_¶¶¶¶¶__¶¶¶¶¶¶__¶¶_¶¶
# ________¶¶¶¶___¶¶¶¶¶__¶¶___¶¶¶¶¶¶¶¶¶¶__¶¶¶¶
# _____________¶¶¶¶¶¶¶¶¶_______¶¶¶¶¶_¶¶¶
# ___________¶¶¶_¶_¶¶¶¶¶______¶¶¶_¶¶¶_¶¶¶¶
# __________¶¶¶_¶_¶¶__¶¶¶_____¶¶¶__¶¶¶__¶¶¶
# _________¶¶_¶¶_¶¶__¶¶_¶_____¶_¶¶__¶¶_¶_¶¶¶
# _______¶¶¶_¶_¶¶¶__¶¶_¶¶_____¶¶_¶___¶¶_¶¶_¶¶¶
# ______¶¶_¶¶_¶¶¶____¶¶¶_______¶¶¶_____¶¶_¶_¶¶¶¶
# _¶¶¶¶¶¶_¶_¶¶¶_________________________¶¶_¶¶_¶¶¶¶¶¶
# ¶¶____¶¶_¶¶¶____________________________¶¶_¶¶____¶
# ¶¶_____¶¶¶¶______________________________¶¶_____¶¶
# _¶¶¶____¶¶_______________________________¶____¶¶¶
# __¶¶¶¶__¶¶_______________________________¶¶¶¶¶¶¶
# ____¶¶¶¶¶_________________________________¶¶¶

# %%
 df = pd.read_csv('/content/movie_profit.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 release_date                             movie  \
# 0           1    6/22/2007                     Evan Almighty
# 1           2    7/28/1995                        Waterworld
# 2           3    5/12/2017  King Arthur: Legend of the Sword
# 3           4   12/25/2013                          47 Ronin
# 4           5    6/22/2018    Jurassic World: Fallen Kingdom
#
#    production_budget  domestic_gross  worldwide_gross   distributor  \
# 0        175000000.0     100289690.0     1.741313e+08     Universal
# 1        175000000.0      88246220.0     2.642462e+08     Universal
# 2        175000000.0      39175066.0     1.399507e+08  Warner Bros.
# 3        175000000.0      38362475.0     1.517168e+08     Universal
# 4        170000000.0     416769345.0     1.304866e+09     Universal
#
#   mpaa_rating      genre
# 0          PG     Comedy
# 1       PG-13     Action
# 2       PG-13  Adventure
# 3       PG-13     Action
# 4       PG-13     Action

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401 entries, 0 to 3400
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3401 non-null   int64
#  1   release_date       3401 non-null   object
#  2   movie              3401 non-null   object
#  3   production_budget  3401 non-null   float64
#  4   domestic_gross     3401 non-null   float64
#  5   worldwide_gross    3401 non-null   float64
#  6   distributor        3353 non-null   object
#  7   mpaa_rating        3264 non-null   object
#  8   genre              3401 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 239.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  production_budget  domestic_gross  worldwide_gross
# count  3401.00000       3.401000e+03    3.401000e+03     3.401000e+03
# mean   1701.00000       3.328474e+07    4.542179e+07     9.411512e+07
# std     981.92846       3.489239e+07    5.882566e+07     1.409182e+08
# min       1.00000       2.500000e+05    0.000000e+00     0.000000e+00
# 25%     851.00000       9.000000e+06    6.118683e+06     1.061881e+07
# 50%    1701.00000       2.000000e+07    2.553382e+07     4.015902e+07
# 75%    2551.00000       4.500000e+07    6.032379e+07     1.176152e+08
# max    3401.00000       1.750000e+08    4.745447e+08     1.304866e+09

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'release_date', 'movie', 'production_budget',
#        'domestic_gross', 'worldwide_gross', 'distributor', 'mpaa_rating',
#        'genre'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
df.head()
# Out:
#   release_date                             movie  production_budget  \
# 0    6/22/2007                     Evan Almighty        175000000.0
# 1    7/28/1995                        Waterworld        175000000.0
# 2    5/12/2017  King Arthur: Legend of the Sword        175000000.0
# 3   12/25/2013                          47 Ronin        175000000.0
# 4    6/22/2018    Jurassic World: Fallen Kingdom        170000000.0
#
#    domestic_gross  worldwide_gross   distributor mpaa_rating      genre
# 0     100289690.0     1.741313e+08     Universal          PG     Comedy
# 1      88246220.0     2.642462e+08     Universal       PG-13     Action
# 2      39175066.0     1.399507e+08  Warner Bros.       PG-13  Adventure
# 3      38362475.0     1.517168e+08     Universal       PG-13     Action
# 4     416769345.0     1.304866e+09     Universal       PG-13     Action

# %%
df.columns = df.columns.str.capitalize()

# %%
df.columns.str.replace("_" , " ")
# Out:
# Index(['Release date', 'Movie', 'Production budget', 'Domestic gross',
#        'Worldwide gross', 'Distributor', 'Mpaa rating', 'Genre'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("_" , " ")

# %%
df.head()
# Out:
#   Release date                             Movie  Production budget  \
# 0    6/22/2007                     Evan Almighty        175000000.0
# 1    7/28/1995                        Waterworld        175000000.0
# 2    5/12/2017  King Arthur: Legend of the Sword        175000000.0
# 3   12/25/2013                          47 Ronin        175000000.0
# 4    6/22/2018    Jurassic World: Fallen Kingdom        170000000.0
#
#    Domestic gross  Worldwide gross   Distributor Mpaa rating      Genre
# 0     100289690.0     1.741313e+08     Universal          PG     Comedy
# 1      88246220.0     2.642462e+08     Universal       PG-13     Action
# 2      39175066.0     1.399507e+08  Warner Bros.       PG-13  Adventure
# 3      38362475.0     1.517168e+08     Universal       PG-13     Action
# 4     416769345.0     1.304866e+09     Universal       PG-13     Action

# %%
sns.boxplot(x = "Genre" , y = 'Worldwide gross' , data = df)
sns.xlabel = "Genre"
sns.ylabel = "Worldwide gross"
sns.title = "Genre vs Worldwide gross"
plt.show()

# %%
df['Profit'] = df['Worldwide gross'] - df['Production budget']

# %%
df['Mpaa rating'].value_counts().plot(kind = 'bar')
plt.xlabel("Mpaa rating")
plt.ylabel("Distribution in Mpaa rating")
plt.title("Mpaa rating vs Distribution")
plt.show()

# %%
df['Year'] = df['Release date'].apply(lambda x : x[-4:])

# %%
df.head()
# Out:
#   Release date                             Movie  Production budget  \
# 0    6/22/2007                     Evan Almighty        175000000.0
# 1    7/28/1995                        Waterworld        175000000.0
# 2    5/12/2017  King Arthur: Legend of the Sword        175000000.0
# 3   12/25/2013                          47 Ronin        175000000.0
# 4    6/22/2018    Jurassic World: Fallen Kingdom        170000000.0
#
#    Domestic gross  Worldwide gross   Distributor Mpaa rating      Genre  \
# 0     100289690.0     1.741313e+08     Universal          PG     Comedy
# 1      88246220.0     2.642462e+08     Universal       PG-13     Action
# 2      39175066.0     1.399507e+08  Warner Bros.       PG-13  Adventure
# 3      38362475.0     1.517168e+08     Universal       PG-13     Action
# 4     416769345.0     1.304866e+09     Universal       PG-13     Action
#
#          Profit  Year
# 0 -8.686710e+05  2007
# 1  8.924622e+07  1995
# 2 -3.504929e+07  2017
# 3 -2.328318e+07  2013
# ...

# %%
plt.figure(figsize=(14, 6))
df.groupby('Year')['Profit'].mean().sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel("Year")
plt.ylabel("Profit")
plt.title("Year vs Profit")
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#        Production budget  Domestic gross  Worldwide gross        Profit
# count       3.401000e+03    3.401000e+03     3.401000e+03  3.401000e+03
# mean        3.328474e+07    4.542179e+07     9.411512e+07  6.083037e+07
# std         3.489239e+07    5.882566e+07     1.409182e+08  1.209349e+08
# min         2.500000e+05    0.000000e+00     0.000000e+00 -1.600000e+08
# 25%         9.000000e+06    6.118683e+06     1.061881e+07 -2.279629e+06
# 50%         2.000000e+07    2.553382e+07     4.015902e+07  1.600869e+07
# 75%         4.500000e+07    6.032379e+07     1.176152e+08  7.483011e+07
# max         1.750000e+08    4.745447e+08     1.304866e+09  1.134866e+09
